# %% [markdown]
# <p style="font-size:26px; line-height:1.8;">
# Perceptual Coding Considering the Threshold of Hearing.
# </p>

# %% [markdown]
# ### 1. Introducción
#
# <p style="font-size:15px; line-height:1.5;">
# El objetivo de esta actividad ha sido realizar una comparación subjetiva entre dos métodos de codificación basados en la Transformada Wavelet Discreta (DWT): temporal_overlapped_DWT_coding.py y dyadic_ToH.py. La primera implementación se caracteriza por utilizar un solapado temporal que suaviza los límites entre bloques, mientras que la segunda incorpora un modelo psicoacústico basado en el umbral de audición (Threshold of Hearing, ToH).
# </p>

# %% [markdown]
# ### 2. Metodología
#
# #### 2.1. Selección del material de audio
#
# <p style="font-size:15px; line-height:1.5;">
# Para realizar la comparación se seleccionaron dos archivos musicales incluidos en el conjunto de datos: VVV - Invierno Nuclear y Annihilator - Liquid Oval. Se escogieron porque presentan características sonoras diferentes y permiten apreciar mejor cómo responde cada método ante distintas circunstancias.
# </p>
#
# #### 2.2. Procedimiento de ejecución
#
# <p style="font-size:15px; line-height:1.5;">
# Ambas implementaciones se ejecutaron en dos condiciones distintas. En la primera fase, se utilizaron parámetros definidos manualmente e idénticos para las dos técnicas, con la intención de obtener un entorno controlado y comparable. Posteriormente, se repitió el experimento dejando que cada script utilizara sus propios valores por defecto, ejecutándolo únicamente con el archivo de entrada.
# </p>

# %% [markdown]
# ### 3. Resultados
#
# #### 3.1. Resultados con parámetros definidos
#
# <p style="font-size:15px; line-height:1.5;">
# Cuando se probaron ambas implementaciones usando los mismos prámetros, la mayoría del grupo notó diferencias claras entre una y otra. Al escucharlas, dio la sensación de que temporal_overload_DWT_coding.py sonaba un poco mejor y ofrecía un sonido algo más agradable, aunque la diferencia era muy ligera.
# </p>
#
# #### 3.2. Resultados con parámetros por defecto
#
# <p style="font-size:15px; line-height:1.5;">
# En la segunda prueba, donde se ejecutó cada script únicamente con los valores por defecto, las diferencias se notaron mucho más. Aunque la configuración por defecto en ambos casos es muy similar, el comportamiento perceptual no lo fue tanto: aquí quedó claro que temporal_overlapped_DWT_coding.py ofrecía un resultado mejor para casi todos. El sonido se escuchaba algo más limpio y más estable. En comparación, dyadic_ToH.py perdía un poco de claridad en algunos fragmentos, lo que hacía que su resultado final se sintiera algo menos nítido. En resumen, en esta prueba sin parámetros, la diferencia fue muy evidente y temporal overlapped destacó claramente como la opción que sonaba mejor.
# </p>

# %% [markdown]
# ### 4. Comandos utilizados
#
# <p style="font-size:15px; line-height:1.5;">
# Para llevar a cabo las distintas pruebas auditivas, se utilizaron los siguientes comandos ejecutados desde la carpeta src del proyecto. Estos comandos permiten procesar los archivos de audio tanto con temporal_overlapped_DWT_coding.py como con dyadic_ToH.py, usando parámetros definidos manualmente y tambie´n con los valores por defecto.
# </p>

# %% [markdown]
# <p style="font-size:15px; line-height:1.5;">
# Nos vamos a la carpeta src:
# </p>

# %%
import os
os.chdir("../src")

# %% [markdown]
# #### 4.1. Ejecución con parámetros definidos

# %%
! python dyadic_ToH.py -f ../data/Annihilator__Liquid_Oval.opus -t 10 -q 8 -s 48000 --show_stats
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# InterCom parameters:
#
# Namespace(input_device=None, output_device=None, list_devices=False, frames_per_second=48000.0, frames_per_chunk=1024, listening_port=4444, destination_address='localhost', destination_port=4444, filename='../data/Annihilator__Liquid_Oval.opus', reading_time=10, number_of_channels=2, show_stats=True, show_samples=False, show_spectrum=False, buffering_time=150, minimal_quantization_step_size=8, rate_control_period=1, wavelet_name='db5', levels='6')
#
# Using device:
#
#    0 Asignador de sonido Microsoft - Input, MME (2 in, 0 out)
# >  1 Varios micrófonos (Intel® Smart, MME (2 in, 0 out)
#    2 Auriculares con micrófono (2- W, MME (1 in, 0 out)
#    3 Asignador de sonido Microsoft - Output, MME (0 in, 2 out)
# <  4 Auriculares (2- WH-CH520), MME (0 in, 2 out)
#    5 Altavoces (Realtek(R) Audio), MME (0 in, 2 out)
#    6 Controlador primario de captura de sonido, Windows DirectSound (2 in, 0 out)
#    7 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows DirectSound (2 in, 0 out)
#    8 Auriculares con micrófono (2- WH-CH520), Windows DirectSound (1 in, 0 out)
#    9 Controlador primario de sonido, Windows DirectSound (0 in, 2 out)
#   10 Auriculares (2- WH-CH520), Windows DirectSound (0 in, 2 out)
#   11 Altavoces (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   12 Altavoces (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   13 Auriculares (2- WH-CH520), Windows WASAPI (0 in, 2 out)
#   14 Auriculares con micrófono (2- WH-CH520), Windows WASAPI (1 in, 0 out)
#   15 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows WASAPI (2 in, 0 out)
#   16 Varios micrófonos (), Windows WDM-KS (2 in, 0 out)
#   17 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (0 in, 1 out)
#   18 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (1 in, 0 out)
#   19 Headphones 1 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   20 Headphones 2 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   21 Altavoz de PC (Realtek HD Audio 2nd output with SST), Windows WDM-KS (2 in, 0 out)
#   22 Mezcla estéreo (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   23 Micrófono (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   24 Speakers 1 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   25 Speakers 2 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   26 Altavoz de PC (Realtek HD Audio output with SST), Windows WDM-KS (2 in, 0 out)
#   27 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   28 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   29 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (0 in, 1 out)
#   30 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (1 in, 0 out)
#
# Use CTRL+C to quit
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
# =============================================================================================================================================
# first_received_chunk_number = 1
#     1      37      37     366     366    7    0 ['  1036', '  4498'] ['11.9', '13.6'] [' 0.0', ' 0.0']    8 ['   21', '   40'] [' 42', ' 55']
# Avgs:      37      37     366     366    7    0 ['  1036', '  4498'] ['11.9', '13.6'] [' 0.0', ' 0.0']      ['   21', '   40'] [' 42', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     2      47      47     527     527   10   12 ['   856', '  3873'] ['11.7', '13.6'] [' 0.0', ' 0.0']    8 ['   44', '   81'] [' 85', '101']
# Avgs:      42      42     446     446    9    6 ['   946', '  4185'] ['11.8', '13.6'] [' 0.0', ' 0.0']      ['   32', '   60'] [' 63', ' 78']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     3      48      48     523     523   10   13 ['   982', '  5638'] ['11.9', '14.0'] [' 0.0', ' 0.0']    8 ['   43', '   81'] [' 85', '111']
# Avgs:      44      44     472     472    9    8 ['   958', '  4670'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   36', '   67'] [' 71', ' 89']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     4      48      48     555     555   10   10 ['   818', '  4709'] ['11.6', '13.8'] [' 0.0', ' 0.0']    8 ['   44', '   89'] [' 85', '103']
# Avgs:      45      45     492     492    9    9 ['   923', '  4680'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   38', '   73'] [' 74', ' 93']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     5      46      46     510     510   10   10 ['  1197', '  4716'] ['12.1', '13.8'] [' 0.0', ' 0.0']    8 ['   43', '   77'] [' 81', '105']
# Avgs:      45      45     496     496   10    9 ['   978', '  4687'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   39', '   74'] [' 76', ' 95']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     6      48      48     562     562    7   10 ['   772', '  3833'] ['11.6', '13.6'] [' 0.0', ' 0.0']    8 ['   48', '   93'] [' 83', '100']
# Avgs:      45      45     507     507    9    9 ['   944', '  4545'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   40', '   77'] [' 77', ' 96']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     7      48      48     547     547   16   11 ['   970', '  5514'] ['11.9', '14.0'] [' 0.0', ' 0.0']    8 ['   47', '   83'] [' 86', '110']
# Avgs:      46      46     512     512   10    9 ['   947', '  4683'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   41', '   78'] [' 78', ' 98']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
# /    8      47      47     546     546   15   18 ['  1191', '  3921'] ['11.9', '13.6'] [' 0.0', ' 0.0']    8 ['   46', '   92'] [' 80', ' 98']
# Avgs:      46      46     516     516   11   10 ['   978', '  4588'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['   42', '   79'] [' 78', ' 98']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     9      48      48     836     836   13   13 ['  6850', '  7228'] ['14.2', '14.2'] [' 0.0', ' 0.0']    8 ['  327', '  391'] [' 80', ' 83']
# Avgs:      46      46     552     552   11   11 ['  1630', '  4881'] ['12.1', '13.8'] [' 0.0', ' 0.0']      ['   74', '  114'] [' 79', ' 96']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#    10      47      47     569     569   20    9 ['  4801', '  5465'] ['13.9', '14.0'] [' 0.0', ' 0.0']    8 ['  147', '  198'] [' 99', ' 95']
# Avgs:      46      46     554     554   12   10 ['  1947', '  4940'] ['12.3', '13.8'] [' 0.0', ' 0.0']      ['   81', '  122'] [' 81', ' 96']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#    11      48      48     561     561   15   10 ['  3025', '  4850'] ['13.3', '13.9'] [' 0.0', ' 0.0']    8 ['   67', '   89'] ['105', '108']
# Avgs:      46      46     554     554   12   10 ['  2045', '  4931'] ['12.4', '13.8'] [' 0.0', ' 0.0']      ['   80', '  119'] [' 83', ' 97']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#
#
#
#
#
# CPU usage average = 12.729202548407349 %
# Payload sent average = 554.7272727272726 kilo bits per second
# Payload received average = 554.7272727272726 kilo bits per second
# Average RMSE (Root Mean Square Error) per sample = [0.00796508 0.01193575]
# Average SNR (Signal Noise Ratio) in decibels = [82.79207321 97.25476198]
# c:\Users\Lenovo\Desktop\InterCom\Entorno\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# (INFO) minimal: A minimal InterCom (no compression, no quantization, no transform, ... only provides a bidirectional (full-duplex) transmission of raw (playable) chunks.
# (INFO) minimal: chunk_time = 0.021333333333333333 seconds
# (INFO) minimal: Using "../data/Annihilator__Liquid_Oval.opus" as input
# (INFO) minimal: seconds_per_cycle = 1
# (INFO) minimal: chunks_per_cycle = 46.875
# (INFO) minimal: frames_per_cycle = 48000.0
# (INFO) buffer: Over minimal, implements a random access buffer structure for hiding the jitter.
# (INFO) buffer: buffering_time = 150 miliseconds
# (INFO) buffer: chunks_to_buffer = 8
# (INFO) buffer: Using "../data/Annihilator__Liquid_Oval.opus" as input
# (INFO) DEFLATE_raw: Compress each raw chunk using DEFLATE.
# (INFO) DEFLATE_byteplanes3: Compress the least significant byte planes of the chunks using DEFLATE. The channels are consecutive (serialized). 3 code-streams (one per byte-plane) are generated.
# (INFO) BR_control_no: No bit-rate control using quantization. In this module, no control
# has been implemented. Both channels are quantized using the same
# constant step size.
# (INFO) BR_control_no: rate_control_period = 1 seconds
# (INFO) BR_control_no: (minimum) quantization_step_size = 8
# (INFO) BR_control_add_lost: Bit-rate control using quantization. Both channels are quantized
# using the same constant step size. To control the quantization step
# size, the number of lost chunks is added to it. Otherwise, the
# quantization step is decremented by 1 each second (by default).
#
#
# (INFO) BR_control_conservative: Bit-rate control using quantization. Both channels are quantized
# using the same constant step. The quantization step is multipled by 2
# each time 2 lost chunks has been detected. Otherwise, the quantization
# step size is divided by 1.1.
# (INFO) stereo_MST_coding_16: MST using 16 bits/coefficient.
# (INFO) stereo_MST_coding_32: MST using 32 bits/coefficient.
# (INFO) temporal_no_overlapped_DWT_coding: Removes the temporal (intra-channel) redundancy using the DWT. First the spatial (inter-channel) redundancy is removed.
# (INFO) temporal_no_overlapped_DWT_coding: wavelet name = db5
# (INFO) temporal_no_overlapped_DWT_coding: analysis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: synthesis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: DWT levels = 6
# (INFO) temporal_overlapped_DWT_coding: Real-time Audio Intercommunicator (removes intra-channel redundancy with a DWT (Discrete Wavelet Transform)).
# (INFO) temporal_overlapped_DWT_coding: number of overlapped samples = 640
# (INFO) temporal_overlapped_DWT_coding: extended chunk size = 2304
# (INFO) dyadic_ToH: Considering the threshold of human hearing.
# (INFO) dyadic_ToH: Quantization step sizes: [184, 56, 40, 16, 8, 56, 512]

# %%
! python dyadic_ToH.py -f ../data/VVV_InviernoNuclear.oga -t 10 -q 8 -s 48000 --show_stats
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# InterCom parameters:
#
# Namespace(input_device=None, output_device=None, list_devices=False, frames_per_second=48000.0, frames_per_chunk=1024, listening_port=4444, destination_address='localhost', destination_port=4444, filename='../data/VVV_InviernoNuclear.oga', reading_time=10, number_of_channels=2, show_stats=True, show_samples=False, show_spectrum=False, buffering_time=150, minimal_quantization_step_size=8, rate_control_period=1, wavelet_name='db5', levels='6')
#
# Using device:
#
#    0 Asignador de sonido Microsoft - Input, MME (2 in, 0 out)
# >  1 Varios micrófonos (Intel® Smart, MME (2 in, 0 out)
#    2 Auriculares con micrófono (2- W, MME (1 in, 0 out)
#    3 Asignador de sonido Microsoft - Output, MME (0 in, 2 out)
# <  4 Auriculares (2- WH-CH520), MME (0 in, 2 out)
#    5 Altavoces (Realtek(R) Audio), MME (0 in, 2 out)
#    6 Controlador primario de captura de sonido, Windows DirectSound (2 in, 0 out)
#    7 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows DirectSound (2 in, 0 out)
#    8 Auriculares con micrófono (2- WH-CH520), Windows DirectSound (1 in, 0 out)
#    9 Controlador primario de sonido, Windows DirectSound (0 in, 2 out)
#   10 Auriculares (2- WH-CH520), Windows DirectSound (0 in, 2 out)
#   11 Altavoces (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   12 Altavoces (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   13 Auriculares (2- WH-CH520), Windows WASAPI (0 in, 2 out)
#   14 Auriculares con micrófono (2- WH-CH520), Windows WASAPI (1 in, 0 out)
#   15 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows WASAPI (2 in, 0 out)
#   16 Varios micrófonos (), Windows WDM-KS (2 in, 0 out)
#   17 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (0 in, 1 out)
#   18 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (1 in, 0 out)
#   19 Headphones 1 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   20 Headphones 2 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   21 Altavoz de PC (Realtek HD Audio 2nd output with SST), Windows WDM-KS (2 in, 0 out)
#   22 Mezcla estéreo (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   23 Micrófono (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   24 Speakers 1 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   25 Speakers 2 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   26 Altavoz de PC (Realtek HD Audio output with SST), Windows WDM-KS (2 in, 0 out)
#   27 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   28 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   29 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (0 in, 1 out)
#   30 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (1 in, 0 out)
#
# Use CTRL+C to quit
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
# =============================================================================================================================================
# first_received_chunk_number = 1
#     1      38      38     257     257   11    0 ['  3724', '  3547'] ['13.4', '13.4'] [' 0.0', ' 0.0']    8 ['   23', '   21'] [' 60', ' 60']
# Avgs:      38      38     257     257   11    0 ['  3724', '  3547'] ['13.4', '13.4'] [' 0.0', ' 0.0']      ['   23', '   21'] [' 60', ' 60']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     2      46      46     333     333   12    8 ['  3963', '  3544'] ['13.6', '13.5'] [' 0.0', ' 0.0']    8 ['   43', '   38'] ['112', '112']
# Avgs:      42      42     295     295   12    4 ['  3844', '  3546'] ['13.5', '13.4'] [' 0.0', ' 0.0']      ['   33', '   30'] [' 86', ' 86']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     3      48      48     347     347   13   10 ['  4017', '  3916'] ['13.6', '13.6'] [' 0.0', ' 0.0']    8 ['   43', '   41'] ['117', '117']
# Avgs:      44      44     312     312   12    6 ['  3901', '  3669'] ['13.6', '13.5'] [' 0.0', ' 0.0']      ['   36', '   33'] [' 96', ' 97']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     4      48      48     354     354    9    9 ['  3966', '  4249'] ['13.6', '13.7'] [' 0.0', ' 0.0']    8 ['   42', '   42'] ['118', '118']
# Avgs:      45      45     322     322   11    7 ['  3917', '  3814'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   38', '   36'] ['102', '102']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     5      48      48     360     360    9    7 ['  3534', '  4152'] ['13.5', '13.7'] [' 0.0', ' 0.0']    8 ['   39', '   46'] ['112', '113']
# Avgs:      45      45     330     330   11    7 ['  3841', '  3882'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   38', '   38'] ['104', '104']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     6      46      46     348     348   15    8 ['  3777', '  4500'] ['13.6', '13.8'] [' 0.0', ' 0.0']    8 ['   40', '   45'] ['112', '112']
# Avgs:      45      45     333     333   11    7 ['  3830', '  3985'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   38', '   39'] ['105', '105']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     7      48      48     362     362   18   10 ['  3571', '  4160'] ['13.5', '13.7'] [' 0.0', ' 0.0']    8 ['   41', '   48'] ['116', '117']
# Avgs:      46      46     337     337   12    7 ['  3793', '  4010'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   39', '   40'] ['107', '107']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     8      48      48     359     359   20   14 ['  3814', '  3488'] ['13.6', '13.5'] [' 0.0', ' 0.0']    8 ['   44', '   44'] ['116', '116']
# Avgs:      46      46     340     340   13    8 ['  3796', '  3945'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   39', '   41'] ['108', '108']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     9      48      48     357     357   16   17 ['  3677', '  3811'] ['13.5', '13.6'] [' 0.0', ' 0.0']    8 ['   44', '   41'] ['110', '110']
# Avgs:      46      46     341     341   14    9 ['  3782', '  3930'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   40', '   41'] ['108', '108']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#    10      46      46     330     330   21   16 ['  4065', '  3877'] ['13.7', '13.6'] [' 0.0', ' 0.0']    8 ['   42', '   41'] ['113', '112']
# Avgs:      46      46     340     340   14   10 ['  3811', '  3924'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['   40', '   41'] ['108', '109']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# c:\Users\Lenovo\Desktop\InterCom\Entorno\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# (INFO) minimal: A minimal InterCom (no compression, no quantization, no transform, ... only provides a bidirectional (full-duplex) transmission of raw (playable) chunks.
# (INFO) minimal: chunk_time = 0.021333333333333333 seconds
# (INFO) minimal: Using "../data/VVV_InviernoNuclear.oga" as input
# (INFO) minimal: seconds_per_cycle = 1
# (INFO) minimal: chunks_per_cycle = 46.875
# (INFO) minimal: frames_per_cycle = 48000.0
# (INFO) buffer: Over minimal, implements a random access buffer structure for hiding the jitter.
# (INFO) buffer: buffering_time = 150 miliseconds
# (INFO) buffer: chunks_to_buffer = 8
# (INFO) buffer: Using "../data/VVV_InviernoNuclear.oga" as input
# (INFO) DEFLATE_raw: Compress each raw chunk using DEFLATE.
# (INFO) DEFLATE_byteplanes3: Compress the least significant byte planes of the chunks using DEFLATE. The channels are consecutive (serialized). 3 code-streams (one per byte-plane) are generated.
# (INFO) BR_control_no: No bit-rate control using quantization. In this module, no control
# has been implemented. Both channels are quantized using the same
# constant step size.
# (INFO) BR_control_no: rate_control_period = 1 seconds
# (INFO) BR_control_no: (minimum) quantization_step_size = 8
# (INFO) BR_control_add_lost: Bit-rate control using quantization. Both channels are quantized
# using the same constant step size. To control the quantization step
# size, the number of lost chunks is added to it. Otherwise, the
# quantization step is decremented by 1 each second (by default).
#
#
# (INFO) BR_control_conservative: Bit-rate control using quantization. Both channels are quantized
# using the same constant step. The quantization step is multipled by 2
# each time 2 lost chunks has been detected. Otherwise, the quantization
# step size is divided by 1.1.
# (INFO) stereo_MST_coding_16: MST using 16 bits/coefficient.
# (INFO) stereo_MST_coding_32: MST using 32 bits/coefficient.
# (INFO) temporal_no_overlapped_DWT_coding: Removes the temporal (intra-channel) redundancy using the DWT. First the spatial (inter-channel) redundancy is removed.
# (INFO) temporal_no_overlapped_DWT_coding: wavelet name = db5
# (INFO) temporal_no_overlapped_DWT_coding: analysis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: synthesis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: DWT levels = 6
# (INFO) temporal_overlapped_DWT_coding: Real-time Audio Intercommunicator (removes intra-channel redundancy with a DWT (Discrete Wavelet Transform)).
# (INFO) temporal_overlapped_DWT_coding: number of overlapped samples = 640
# (INFO) temporal_overlapped_DWT_coding: extended chunk size = 2304
# (INFO) dyadic_ToH: Considering the threshold of human hearing.
# (INFO) dyadic_ToH: Quantization step sizes: [184, 56, 40, 16, 8, 56, 512]
# (WARNING) minimal: Input exhausted! :-/

# %% [markdown]
# <p style="font-size:15px; line-height:1.5;">
# En estas ejecuciones se ajustaron manualmente los valores de:<br>
# - niveles DWT (-t 10)<br>
# - cuantización (-q 8)<br>
# - frecuencia de muestreo (-s 48000)
# </p>

# %% [markdown]
# #### 4.2. Ejecución con los valores por defecto

# %%
! python dyadic_ToH.py -f ../data/Annihilator__Liquid_Oval.opus -t 10 --show_stats
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# InterCom parameters:
#
# Namespace(input_device=None, output_device=None, list_devices=False, frames_per_second=44100, frames_per_chunk=1024, listening_port=4444, destination_address='localhost', destination_port=4444, filename='../data/Annihilator__Liquid_Oval.opus', reading_time=10, number_of_channels=2, show_stats=True, show_samples=False, show_spectrum=False, buffering_time=150, minimal_quantization_step_size=128, rate_control_period=1, wavelet_name='db5', levels='6')
#
# Using device:
#
#    0 Asignador de sonido Microsoft - Input, MME (2 in, 0 out)
# >  1 Varios micrófonos (Intel® Smart, MME (2 in, 0 out)
#    2 Auriculares con micrófono (2- W, MME (1 in, 0 out)
#    3 Asignador de sonido Microsoft - Output, MME (0 in, 2 out)
# <  4 Auriculares (2- WH-CH520), MME (0 in, 2 out)
#    5 Altavoces (Realtek(R) Audio), MME (0 in, 2 out)
#    6 Controlador primario de captura de sonido, Windows DirectSound (2 in, 0 out)
#    7 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows DirectSound (2 in, 0 out)
#    8 Auriculares con micrófono (2- WH-CH520), Windows DirectSound (1 in, 0 out)
#    9 Controlador primario de sonido, Windows DirectSound (0 in, 2 out)
#   10 Auriculares (2- WH-CH520), Windows DirectSound (0 in, 2 out)
#   11 Altavoces (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   12 Altavoces (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   13 Auriculares (2- WH-CH520), Windows WASAPI (0 in, 2 out)
#   14 Auriculares con micrófono (2- WH-CH520), Windows WASAPI (1 in, 0 out)
#   15 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows WASAPI (2 in, 0 out)
#   16 Varios micrófonos (), Windows WDM-KS (2 in, 0 out)
#   17 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (0 in, 1 out)
#   18 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (1 in, 0 out)
#   19 Headphones 1 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   20 Headphones 2 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   21 Altavoz de PC (Realtek HD Audio 2nd output with SST), Windows WDM-KS (2 in, 0 out)
#   22 Mezcla estéreo (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   23 Micrófono (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   24 Speakers 1 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   25 Speakers 2 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   26 Altavoz de PC (Realtek HD Audio output with SST), Windows WDM-KS (2 in, 0 out)
#   27 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   28 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   29 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (0 in, 1 out)
#   30 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (1 in, 0 out)
#
# Use CTRL+C to quit
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
# =============================================================================================================================================
# first_received_chunk_number = 1
#     1      40      40     195     195   10    0 ['  1051', '  4418'] ['11.9', '13.7'] [' 0.0', ' 0.0']  128 ['  265', '  580'] [' 27', ' 40']
# Avgs:      40      40     195     195   10    0 ['  1051', '  4418'] ['11.9', '13.7'] [' 0.0', ' 0.0']      ['  265', '  580'] [' 27', ' 40']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     2      44      44     241     241    7    9 ['   825', '  3893'] ['11.6', '13.6'] [' 0.0', ' 0.0']  128 ['  443', '  942'] [' 40', ' 55']
# Avgs:      42      42     218     218    9    4 ['   938', '  4155'] ['11.8', '13.6'] [' 0.0', ' 0.0']      ['  354', '  761'] [' 34', ' 47']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     3      44      44     246     246   12   10 ['  1001', '  5712'] ['11.9', '14.0'] [' 0.0', ' 0.0']  128 ['  370', '  870'] [' 42', ' 63']
# Avgs:      42      42     227     227   10    6 ['   959', '  4674'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['  359', '  797'] [' 36', ' 53']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
# \    4      43      43     263     263   15   11 ['   866', '  4624'] ['11.7', '13.8'] [' 0.0', ' 0.0']  128 ['  441', '  988'] [' 40', ' 54']
# Avgs:      42      42     236     236   11    7 ['   936', '  4662'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['  380', '  845'] [' 37', ' 53']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     5      43      43     232     232    9    6 ['  1136', '  4944'] ['12.0', '13.8'] [' 0.0', ' 0.0']  128 ['  383', '  877'] [' 40', ' 61']
# Avgs:      42      42     235     235   11    7 ['   976', '  4718'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['  381', '  851'] [' 38', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     6      44      44     282     282    7   12 ['   845', '  3683'] ['11.7', '13.5'] [' 0.0', ' 0.0']  128 ['  453', ' 1020'] [' 40', ' 54']
# Avgs:      43      43     243     243   10    8 ['   954', '  4546'] ['11.8', '13.7'] [' 0.0', ' 0.0']      ['  393', '  879'] [' 38', ' 54']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     7      44      44     244     244    9   16 ['   980', '  5366'] ['11.9', '14.0'] [' 0.0', ' 0.0']  128 ['  430', '  966'] [' 40', ' 59']
# Avgs:      43      43     243     243   10    9 ['   958', '  4663'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['  398', '  892'] [' 39', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     8      44      44     279     279    7   12 ['  1067', '  4374'] ['12.0', '13.7'] [' 0.0', ' 0.0']  128 ['  420', '  897'] [' 40', ' 57']
# Avgs:      43      43     247     247    9    9 ['   972', '  4627'] ['11.8', '13.8'] [' 0.0', ' 0.0']      ['  401', '  892'] [' 39', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     9      44      44     349     349   12   12 ['  5255', '  6000'] ['13.1', '13.9'] [' 0.0', ' 0.0']  128 ['  709', ' 1223'] [' 40', ' 52']
# Avgs:      43      43     259     259   10   10 ['  1447', '  4779'] ['12.0', '13.8'] [' 0.0', ' 0.0']      ['  435', '  929'] [' 39', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#    10      43      43     380     380    9    5 ['  6094', '  6735'] ['14.0', '14.1'] [' 0.0', ' 0.0']  128 [' 1186', ' 1478'] [' 58', ' 56']
# Avgs:      43      43     271     271   10    9 ['  1912', '  4975'] ['12.2', '13.8'] [' 0.0', ' 0.0']      ['  510', '  984'] [' 41', ' 55']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#
#
#
#
#
# CPU usage average = 10.133881040648111 %
# Payload sent average = 271.1 kilo bits per second
# Payload received average = 271.1 kilo bits per second
# Average RMSE (Root Mean Square Error) per sample = [0.0510152  0.09839111]
# Average SNR (Signal Noise Ratio) in decibels = [40.7229853  55.08228866]
# c:\Users\Lenovo\Desktop\InterCom\Entorno\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# (INFO) minimal: A minimal InterCom (no compression, no quantization, no transform, ... only provides a bidirectional (full-duplex) transmission of raw (playable) chunks.
# (INFO) minimal: chunk_time = 0.023219954648526078 seconds
# (INFO) minimal: Using "../data/Annihilator__Liquid_Oval.opus" as input
# (INFO) minimal: seconds_per_cycle = 1
# (INFO) minimal: chunks_per_cycle = 43.06640625
# (INFO) minimal: frames_per_cycle = 44100
# (INFO) buffer: Over minimal, implements a random access buffer structure for hiding the jitter.
# (INFO) buffer: buffering_time = 150 miliseconds
# (INFO) buffer: chunks_to_buffer = 7
# (INFO) buffer: Using "../data/Annihilator__Liquid_Oval.opus" as input
# (INFO) DEFLATE_raw: Compress each raw chunk using DEFLATE.
# (INFO) DEFLATE_byteplanes3: Compress the least significant byte planes of the chunks using DEFLATE. The channels are consecutive (serialized). 3 code-streams (one per byte-plane) are generated.
# (INFO) BR_control_no: No bit-rate control using quantization. In this module, no control
# has been implemented. Both channels are quantized using the same
# constant step size.
# (INFO) BR_control_no: rate_control_period = 1 seconds
# (INFO) BR_control_no: (minimum) quantization_step_size = 128
# (INFO) BR_control_add_lost: Bit-rate control using quantization. Both channels are quantized
# using the same constant step size. To control the quantization step
# size, the number of lost chunks is added to it. Otherwise, the
# quantization step is decremented by 1 each second (by default).
#
#
# (INFO) BR_control_conservative: Bit-rate control using quantization. Both channels are quantized
# using the same constant step. The quantization step is multipled by 2
# each time 2 lost chunks has been detected. Otherwise, the quantization
# step size is divided by 1.1.
# (INFO) stereo_MST_coding_16: MST using 16 bits/coefficient.
# (INFO) stereo_MST_coding_32: MST using 32 bits/coefficient.
# (INFO) temporal_no_overlapped_DWT_coding: Removes the temporal (intra-channel) redundancy using the DWT. First the spatial (inter-channel) redundancy is removed.
# (INFO) temporal_no_overlapped_DWT_coding: wavelet name = db5
# (INFO) temporal_no_overlapped_DWT_coding: analysis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: synthesis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: DWT levels = 6
# (INFO) temporal_overlapped_DWT_coding: Real-time Audio Intercommunicator (removes intra-channel redundancy with a DWT (Discrete Wavelet Transform)).
# (INFO) temporal_overlapped_DWT_coding: number of overlapped samples = 640
# (INFO) temporal_overlapped_DWT_coding: extended chunk size = 2304
# (INFO) dyadic_ToH: Considering the threshold of human hearing.
# (INFO) dyadic_ToH: Quantization step sizes: [2944, 896, 640, 256, 128, 896, 8192]

# %%
! python dyadic_ToH.py -f ../data/VVV_InviernoNuclear.oga --show_stats
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# InterCom parameters:
#
# Namespace(input_device=None, output_device=None, list_devices=False, frames_per_second=44100, frames_per_chunk=1024, listening_port=4444, destination_address='localhost', destination_port=4444, filename='../data/VVV_InviernoNuclear.oga', reading_time=None, number_of_channels=2, show_stats=True, show_samples=False, show_spectrum=False, buffering_time=150, minimal_quantization_step_size=128, rate_control_period=1, wavelet_name='db5', levels='6')
#
# Using device:
#
#    0 Asignador de sonido Microsoft - Input, MME (2 in, 0 out)
# >  1 Varios micrófonos (Intel® Smart, MME (2 in, 0 out)
#    2 Auriculares con micrófono (2- W, MME (1 in, 0 out)
#    3 Asignador de sonido Microsoft - Output, MME (0 in, 2 out)
# <  4 Auriculares (2- WH-CH520), MME (0 in, 2 out)
#    5 Altavoces (Realtek(R) Audio), MME (0 in, 2 out)
#    6 Controlador primario de captura de sonido, Windows DirectSound (2 in, 0 out)
#    7 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows DirectSound (2 in, 0 out)
#    8 Auriculares con micrófono (2- WH-CH520), Windows DirectSound (1 in, 0 out)
#    9 Controlador primario de sonido, Windows DirectSound (0 in, 2 out)
#   10 Auriculares (2- WH-CH520), Windows DirectSound (0 in, 2 out)
#   11 Altavoces (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   12 Altavoces (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   13 Auriculares (2- WH-CH520), Windows WASAPI (0 in, 2 out)
#   14 Auriculares con micrófono (2- WH-CH520), Windows WASAPI (1 in, 0 out)
#   15 Varios micrófonos (Intel® Smart Sound Technology for Digital Microphones), Windows WASAPI (2 in, 0 out)
#   16 Varios micrófonos (), Windows WDM-KS (2 in, 0 out)
#   17 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (0 in, 1 out)
#   18 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(Vieta Pro Done 4)), Windows WDM-KS (1 in, 0 out)
#   19 Headphones 1 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   20 Headphones 2 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   21 Altavoz de PC (Realtek HD Audio 2nd output with SST), Windows WDM-KS (2 in, 0 out)
#   22 Mezcla estéreo (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   23 Micrófono (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   24 Speakers 1 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   25 Speakers 2 (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   26 Altavoz de PC (Realtek HD Audio output with SST), Windows WDM-KS (2 in, 0 out)
#   27 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   28 Auriculares (), Windows WDM-KS (0 in, 2 out)
#   29 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (0 in, 1 out)
#   30 Auriculares con micrófono (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
#
# ;(WH-CH520)), Windows WDM-KS (1 in, 0 out)
#
# Use CTRL+C to quit
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
# =============================================================================================================================================
# first_received_chunk_number = 1
#     1      40      40     172     172    1    0 ['  3753', '  3489'] ['13.5', '13.4'] [' 0.0', ' 0.0']  128 ['  442', '  383'] [' 42', ' 43']
# Avgs:      40      40     172     172    1    0 ['  3753', '  3489'] ['13.5', '13.4'] [' 0.0', ' 0.0']      ['  442', '  383'] [' 42', ' 43']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     2      44      44     207     207   13   13 ['  3943', '  3573'] ['13.6', '13.5'] [' 0.0', ' 0.0']  128 ['  635', '  575'] [' 64', ' 64']
# Avgs:      42      42     189     189    7    6 ['  3848', '  3531'] ['13.5', '13.4'] [' 0.0', ' 0.0']      ['  539', '  479'] [' 53', ' 53']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     3      44      44     206     206    6   11 ['  4034', '  3950'] ['13.6', '13.6'] [' 0.0', ' 0.0']  128 ['  606', '  560'] [' 61', ' 62']
# Avgs:      42      42     195     195    7    8 ['  3910', '  3671'] ['13.6', '13.5'] [' 0.0', ' 0.0']      ['  561', '  506'] [' 56', ' 56']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     4      43      43     201     201    9    9 ['  3918', '  3951'] ['13.6', '13.6'] [' 0.0', ' 0.0']  128 ['  580', '  588'] [' 62', ' 61']
# Avgs:      42      42     196     196    7    8 ['  3912', '  3741'] ['13.6', '13.5'] [' 0.0', ' 0.0']      ['  566', '  527'] [' 57', ' 57']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     5      43      43     210     210    9   10 ['  3644', '  4472'] ['13.5', '13.7'] [' 0.0', ' 0.0']  128 ['  555', '  635'] [' 63', ' 64']
# Avgs:      42      42     199     199    8    9 ['  3859', '  3887'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['  563', '  548'] [' 58', ' 59']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     6      44      44     212     212   10   13 ['  3739', '  4189'] ['13.5', '13.7'] [' 0.0', ' 0.0']  128 ['  574', '  671'] [' 64', ' 64']
# Avgs:      43      43     201     201    8    9 ['  3839', '  3937'] ['13.6', '13.6'] [' 0.0', ' 0.0']      ['  565', '  569'] [' 59', ' 60']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     7      44      44     211     211    9   16 ['  3577', '  4400'] ['13.5', '13.7'] [' 0.0', ' 0.0']  128 ['  573', '  634'] [' 64', ' 66']
# Avgs:      43      43     202     202    8   10 ['  3801', '  4004'] ['13.5', '13.6'] [' 0.0', ' 0.0']      ['  566', '  578'] [' 60', ' 60']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     8      44      44     212     212    4   22 ['  3684', '  3959'] ['13.5', '13.6'] [' 0.0', ' 0.0']  128 ['  566', '  630'] [' 65', ' 65']
# Avgs:      43      43     203     203    8   12 ['  3787', '  3998'] ['13.5', '13.6'] [' 0.0', ' 0.0']      ['  566', '  585'] [' 61', ' 61']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#     9      44      44     209     209    6   32 ['  3737', '  3516'] ['13.5', '13.4'] [' 0.0', ' 0.0']  128 ['  633', '  562'] [' 61', ' 62']
# Avgs:      43      43     204     204    7   14 ['  3781', '  3944'] ['13.5', '13.6'] [' 0.0', ' 0.0']      ['  574', '  582'] [' 61', ' 61']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
#
#    10      44      44     210     210    9   21 ['  3897', '  3854'] ['13.6', '13.6'] [' 0.0', ' 0.0']  128 ['  602', '  559'] [' 60', ' 61']
# Avgs:      43      43     205     205    8   15 ['  3793', '  3935'] ['13.5', '13.6'] [' 0.0', ' 0.0']      ['  577', '  580'] [' 61', ' 61']
# =============================================================================================================================================
# cycle  mesgs.  mesgs.    KBPS    KBPS %CPU %CPU   standard deviation          entropy      bits/sample    Q        RMSE/sample        SNR[dB]
#          sent   recv.    sent    recv.   Global          input audio      input audio           output                  10^4 *
# c:\Users\Lenovo\Desktop\InterCom\Entorno\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# (INFO) minimal: A minimal InterCom (no compression, no quantization, no transform, ... only provides a bidirectional (full-duplex) transmission of raw (playable) chunks.
# (INFO) minimal: chunk_time = 0.023219954648526078 seconds
# (INFO) minimal: Using "../data/VVV_InviernoNuclear.oga" as input
# (INFO) minimal: seconds_per_cycle = 1
# (INFO) minimal: chunks_per_cycle = 43.06640625
# (INFO) minimal: frames_per_cycle = 44100
# (INFO) buffer: Over minimal, implements a random access buffer structure for hiding the jitter.
# (INFO) buffer: buffering_time = 150 miliseconds
# (INFO) buffer: chunks_to_buffer = 7
# (INFO) buffer: Using "../data/VVV_InviernoNuclear.oga" as input
# (INFO) DEFLATE_raw: Compress each raw chunk using DEFLATE.
# (INFO) DEFLATE_byteplanes3: Compress the least significant byte planes of the chunks using DEFLATE. The channels are consecutive (serialized). 3 code-streams (one per byte-plane) are generated.
# (INFO) BR_control_no: No bit-rate control using quantization. In this module, no control
# has been implemented. Both channels are quantized using the same
# constant step size.
# (INFO) BR_control_no: rate_control_period = 1 seconds
# (INFO) BR_control_no: (minimum) quantization_step_size = 128
# (INFO) BR_control_add_lost: Bit-rate control using quantization. Both channels are quantized
# using the same constant step size. To control the quantization step
# size, the number of lost chunks is added to it. Otherwise, the
# quantization step is decremented by 1 each second (by default).
#
#
# (INFO) BR_control_conservative: Bit-rate control using quantization. Both channels are quantized
# using the same constant step. The quantization step is multipled by 2
# each time 2 lost chunks has been detected. Otherwise, the quantization
# step size is divided by 1.1.
# (INFO) stereo_MST_coding_16: MST using 16 bits/coefficient.
# (INFO) stereo_MST_coding_32: MST using 32 bits/coefficient.
# (INFO) temporal_no_overlapped_DWT_coding: Removes the temporal (intra-channel) redundancy using the DWT. First the spatial (inter-channel) redundancy is removed.
# (INFO) temporal_no_overlapped_DWT_coding: wavelet name = db5
# (INFO) temporal_no_overlapped_DWT_coding: analysis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: synthesis filters's length = 10
# (INFO) temporal_no_overlapped_DWT_coding: DWT levels = 6
# (INFO) temporal_overlapped_DWT_coding: Real-time Audio Intercommunicator (removes intra-channel redundancy with a DWT (Discrete Wavelet Transform)).
# (INFO) temporal_overlapped_DWT_coding: number of overlapped samples = 640
# (INFO) temporal_overlapped_DWT_coding: extended chunk size = 2304
# (INFO) dyadic_ToH: Considering the threshold of human hearing.
# (INFO) dyadic_ToH: Quantization step sizes: [2944, 896, 640, 256, 128, 896, 8192]
# (WARNING) minimal: Input exhausted! :-/

# %% [markdown]
# ### 5. Conclusiones
#
# <p style="font-size:15px; line-height:1.5;">
# Aunque durante la práctica no siempre fue sencillo apreciar difencias marcadas entre ambas implementaciones, lo realmente importante fue la comparación realizada utilizando los valores que ajustamos nosotros mismos. Esa configuración es la que permite que las dos técnicas operen bajo las mismas condiciones, y por tanto, la que ofrece una comparación jsuta entre ellas. En ese escenario controlado, el grupo coincidió en que temporal_overlapped_DWT_coding.py proporcionaba un resultado perceptualmente mejor. Las pruebas con los valores por defecto simplemente ayudaron a reforzar esta impresión, pero la conclusió válida es la obtenida con los parámetros que fijamos de forma manual: la versión basada en solapado temporal fue la que ofreció la mejor calidad auditiva.
# </p>

# %% [markdown]
# ### Participantes:<br>
#
#
# Leilla Benkhajjou Mezgar<br>
# Antonio Galindo Pérez<br>
# Paola García Cárdenas<br>
# Blanca Romero Rodríguez<br>
# Francisco Javier Ruiz Veiga<br>
